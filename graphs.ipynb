# %%
import matplotlib.pyplot as plt

# %%
epochs = range(1, 6)
loss_svd_2 = [0.8402656302849452, 0.628484205643336, 0.5941954678297043, 0.571972493092219, 0.558251717766126]
val_loss_svd_2 = [0.6722726641183204, 0.5922492712419084, 0.5749907992938732, 0.5664505663704364, 0.5628150801392312]
val_accuracy_svd_2 = [0.739125, 0.7750833333333333, 0.784875, 0.784375, 0.7866666666666666]

loss_svd_3 = [0.8979273507595062, 0.6969741060733795, 0.6555242583354314, 0.6296632038354874, 0.6140209552049637]
val_loss_svd_3 = [0.7557354185809481, 0.6750836039477206, 0.6248653385233371, 0.6104654003965094, 0.6262611827634751]
val_accuracy_svd_3 = [0.702125, 0.7379166666666667, 0.7648333333333334, 0.7679166666666667, 0.7580833333333333]

loss_svd_5 = [0.9506065978209177, 0.7255829363663991, 0.676269496122996, 0.6503515508969625, 0.6298549388647079]
val_loss_svd_5 = [0.7747147165714426, 0.7143118162738517, 0.663264735899073, 0.6263120738749809, 0.6467263392628507]
val_accuracy_svd_5 = [0.69375, 0.7181666666666666, 0.7447083333333333, 0.760875, 0.750125]

# %%
loss_skip_2 = [0.5473438397844632, 0.29461914736032485, 0.23133309352397918, 0.18838504072030385, 0.1519753182878097]
val_loss_skip_2 = [0.34576361182522264, 0.31845785598171517, 0.3006420649112539, 0.31645214367420116, 0.3474993185001485]
val_accuracy_skip_2 = [0.8775416666666667, 0.8880833333333333, 0.8955416666666667, 0.895, 0.8875833333333333]

loss_skip_3 = [0.4065282931129138, 0.2788334895571073, 0.23271842606862386, 0.19431116285920144, 0.15955332568784555]
val_loss_skip_3 = [0.3113686975012434, 0.27573607933331046, 0.2688020652437464, 0.2786768815935926, 0.28579322684635505]
val_accuracy_skip_3 = [0.887875, 0.9024583333333334, 0.9059583333333333, 0.9063333333333333, 0.90725]

loss_skip_5 = [0.3758609892129898, 0.26544497545560203, 0.2236557275255521, 0.18650353069106737, 0.1489622383316358]
val_loss_skip_5 = [0.3018898256123066, 0.2660557547623807, 0.26236808775587284, 0.25820167426099166, 0.27613336985257075]
val_accuracy_skip_5 = [0.890125, 0.9062916666666667, 0.9089166666666667, 0.9110833333333334, 0.912125]

# %%
# plot 3 graphs for svd loss, accuracy and val_loss

plt.figure(figsize=(15, 5))
# add title
plt.suptitle('SVD with different context sizes')
plt.subplot(1, 3, 1)
plt.plot(epochs, loss_svd_2, 'ro-', label='SVD 2')
plt.plot(epochs, loss_svd_3, 'bo-', label='SVD 3')
plt.plot(epochs, loss_svd_5, 'go-', label='SVD 5')
plt.title('SVD Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(epochs, val_accuracy_svd_2, 'ro-', label='SVD 2')
plt.plot(epochs, val_accuracy_svd_3, 'bo-', label='SVD 3')
plt.plot(epochs, val_accuracy_svd_5, 'go-', label='SVD 5')
plt.title('SVD Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(epochs, val_loss_svd_2, 'ro-', label='SVD 2')
plt.plot(epochs, val_loss_svd_3, 'bo-', label='SVD 3')
plt.plot(epochs, val_loss_svd_5, 'go-', label='SVD 5')
plt.title('SVD Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
# ave image
plt.tight_layout()

plt.savefig('svd.png')

# %%
# plot 3 graphs for svd loss, accuracy and val_loss

plt.figure(figsize=(15, 5))
# add title
plt.suptitle('Skip Gram with different context sizes')
plt.subplot(1, 3, 1)
plt.plot(epochs, loss_skip_2, 'ro-', label='Skip Gram 2')
plt.plot(epochs, loss_skip_3, 'bo-', label='Skip Gram 3')
plt.plot(epochs, loss_skip_5, 'go-', label='Skip Gram 5')
plt.title('Skip Gram Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(epochs, val_accuracy_skip_2, 'ro-', label='Skip Gram 2')
plt.plot(epochs, val_accuracy_skip_3, 'bo-', label='Skip Gram 3')
plt.plot(epochs, val_accuracy_skip_5, 'go-', label='Skip Gram 5')
plt.title('Skip Gram Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(epochs, val_loss_skip_2, 'ro-', label='Skip Gram 2')
plt.plot(epochs, val_loss_skip_3, 'bo-', label='Skip Gram 3')
plt.plot(epochs, val_loss_skip_5, 'go-', label='Skip Gram 5')
plt.title('Skip Gram Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('skip.png')

# %%
# comparing best performing models
plt.figure(figsize=(15, 5))
# plot 3 graphs for svd loss, accuracy and val_loss

plt.figure(figsize=(15, 5))
# add title
plt.suptitle('Comparing best models')
plt.subplot(1, 3, 1)
plt.plot(epochs, loss_svd_2, color='#4EBA19', linestyle='-', marker='o', label='SVD 2')
plt.plot(epochs, loss_skip_5, color='#E5007D', linestyle='-', marker='o', label='Skip Gram 5')
plt.title('Train Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(epochs, val_accuracy_svd_2, color='#4EBA19', linestyle='-', marker='o', label='SVD 2')
plt.plot(epochs, val_accuracy_skip_5, color='#E5007D', linestyle='-', marker='o', label='Skip Gram 5')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(epochs, val_loss_svd_2, color='#4EBA19', linestyle='-', marker='o', label='SVD 2')
plt.plot(epochs, val_loss_skip_5, color='#E5007D', linestyle='-', marker='o', label='Skip Gram 5')
plt.title('Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('best_models.png')

# %%
import matplotlib.pyplot as plt

# Data
contexts = ['2', '3', '5']
test_accuracy = [0.8810526315789474, 0.9002631578947369, 0.9078947368421053]
precision = [0.883443796770095, 0.901288152354631, 0.9085722912330643]
recall = [0.8810526315789473, 0.9002631578947369, 0.9078947368421053]
f1_score = [0.8812471612294172, 0.9004030174895656, 0.9080224256745376]

# Plot horizontal bar graphs for each metric
plt.figure(figsize=(12, 5))

# Test Accuracy
plt.subplot(2, 2, 1)
plt.barh(contexts, test_accuracy, color='b', height=0.4)
plt.title('Accuracy')
plt.xlabel('Accuracy')
plt.ylabel('Context Size')
plt.xlim(0.70, 1)

# Precision
plt.subplot(2, 2, 2)
plt.barh(contexts, precision, color='r', height=0.4)
plt.title('Precision')
plt.xlabel('Precision')
plt.ylabel('Context Size')
plt.xlim(0.70, 1)

# Recall
plt.subplot(2, 2, 3)
plt.barh(contexts, recall, color='g', height=0.4)
plt.title('Recall')
plt.xlabel('Recall')
plt.ylabel('Context Size')
plt.xlim(0.70, 1)

# F1 Score
plt.subplot(2, 2, 4)
plt.barh(contexts, f1_score, color='purple', height=0.4)
plt.title('F1 Score')
plt.xlabel('F1 Score')
plt.ylabel('Context Size')
plt.xlim(0.70, 1)

# Adjust layout
plt.tight_layout()
# give a heading to the entire plot
plt.suptitle('Performance Metrics for Different Context Sizes (Skip Gram)')

# Show the plots
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
contexts = ['2', '3', '5']
test_accuracy = [0.7825, 0.7576315789473684, 0.7553947368421052]
precision = [0.7882821574023594, 0.7755842718077535, 0.7659318997302369]
recall = [0.7825, 0.7576315789473684, 0.7553947368421052]
f1_score = [0.7803599553367888, 0.757128272705012, 0.7556074831911865]

# Plot horizontal bar graphs for each metric
plt.figure(figsize=(12, 5))

# Test Accuracy
plt.subplot(2, 2, 1)
plt.barh(contexts, test_accuracy, color='b', height=0.4)
plt.title('Accuracy')
plt.xlabel('Accuracy')
plt.ylabel('Context Size')
plt.xlim(0.70, 1)

# Precision
plt.subplot(2, 2, 2)
plt.barh(contexts, precision, color='r', height=0.4)
plt.title('Precision')
plt.xlabel('Precision')
plt.ylabel('Context Size')
plt.xlim(0.70, 1)

# Recall
plt.subplot(2, 2, 3)
plt.barh(contexts, recall, color='g', height=0.4)
plt.title('Recall')
plt.xlabel('Recall')
plt.ylabel('Context Size')
plt.xlim(0.70, 1)

# F1 Score
plt.subplot(2, 2, 4)
plt.barh(contexts, f1_score, color='purple', height=0.4)
plt.title('F1 Score')
plt.xlabel('F1 Score')
plt.ylabel('Context Size')
plt.xlim(0.70, 1)

# Adjust layout
plt.tight_layout()
# give a heading to the entire plot
plt.suptitle('Performance Metrics for Different Context Sizes (SVD)')

# Show the plots
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
svd_scores = [0.7825, 0.7882821574023594, 0.7825, 0.7803599553367888]
skipgram_scores = [0.9078947368421053, 0.9085722912330643, 0.9078947368421053, 0.9080224256745376]
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']  # Custom color codes
bar_width = 0.6  # Adjust the width of the bars

# Plot subplots for each metric
plt.figure(figsize=(8, 8))
plt.suptitle('Comparing SVD and Skip-gram Models')


# Test Accuracy
plt.subplot(2, 2, 1)
plt.bar(['SVD', 'Skip-gram'], [svd_scores[0], skipgram_scores[0]], color=[colors[0], colors[0]], alpha=0.7, width=bar_width)
plt.title(metrics[0])
plt.ylabel('Scores')

# Precision
plt.subplot(2, 2, 2)
plt.bar(['SVD', 'Skip-gram'], [svd_scores[1], skipgram_scores[1]], color=[colors[1], colors[1]], alpha=0.7, width=bar_width)
plt.title(metrics[1])

# Recall
plt.subplot(2, 2, 3)
plt.bar(['SVD', 'Skip-gram'], [svd_scores[2], skipgram_scores[2]], color=[colors[2], colors[2]], alpha=0.7, width=bar_width)
plt.title(metrics[2])
plt.ylabel('Scores')

# F1 Score
plt.subplot(2, 2, 4)
plt.bar(['SVD', 'Skip-gram'], [svd_scores[3], skipgram_scores[3]], color=[colors[3], colors[3]], alpha=0.7, width=bar_width)
plt.title(metrics[3])

# Adjust layout
plt.tight_layout()
# add title

# Show the plot
plt.show()
